# %%
import seaborn as sns 
import pandas as pd

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
data=sns.load_dataset("planets")

# %%
data
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
data.describe()
# Out:
#             number  orbital_period        mass     distance         year
# count  1035.000000      992.000000  513.000000   808.000000  1035.000000
# mean      1.785507     2002.917596    2.638161   264.069282  2009.070531
# std       1.240976    26014.728304    3.818617   733.116493     3.972567
# min       1.000000        0.090706    0.003600     1.350000  1989.000000
# 25%       1.000000        5.442540    0.229000    32.560000  2007.000000
# 50%       1.000000       39.979500    1.260000    55.250000  2010.000000
# 75%       2.000000      526.005000    3.040000   178.500000  2012.000000
# max       7.000000   730000.000000   25.000000  8500.000000  2014.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   method          1035 non-null   object
#  1   number          1035 non-null   int64
#  2   orbital_period  992 non-null    float64
#  3   mass            513 non-null    float64
#  4   distance        808 non-null    float64
#  5   year            1035 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(3), int64(1), object(1)
# memory usage: 48.6+ KB

# %%
data["year"]=pd.to_datetime(data["year"])

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [method, number, orbital_period, mass, distance, year]
# Index: []

# %%
data=data.drop_duplicates()

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# method            0
# number            0
# orbital_period    0
# mass              0
# distance          0
# year              0
# dtype: int64

# %%
data=data.dropna()

# %%
data
# Out:
#               method  number  orbital_period    mass  distance  \
# 0    Radial Velocity       1       269.30000   7.100     77.40
# 1    Radial Velocity       1       874.77400   2.210     56.95
# 2    Radial Velocity       1       763.00000   2.600     19.84
# 3    Radial Velocity       1       326.03000  19.400    110.62
# 4    Radial Velocity       1       516.22000  10.500    119.47
# ..               ...     ...             ...     ...       ...
# 640  Radial Velocity       1       111.70000   2.100     14.90
# 641  Radial Velocity       1         5.05050   1.068     44.46
# 642  Radial Velocity       1       311.28800   1.940     17.24
# 649          Transit       1         2.70339   1.470    178.00
# 784  Radial Velocity       3       580.00000   0.947    135.00
#
#                              year
# 0   1970-01-01 00:00:00.000002006
# 1   1970-01-01 00:00:00.000002008
# 2   1970-01-01 00:00:00.000002011
# 3   1970-01-01 00:00:00.000002007
# ...

# %%
# Distribution of variables

# %%
sns.displot(data["mass"],kind="ecdf")
sns.set_theme("talk")
sns.set_style("ticks")

# %%
sns.displot(data["mass"],kind="kde",fill=True,color="black")
#sns.set("poster")
sns.set_style("white")

# %%
sns.displot(data["mass"],kind="hist",fill=True,bins=15,color="r")
sns.set("poster")
sns.set_style("whitegrid")

# %% [markdown]
# # relationship between numerical variable

# %%
sns.relplot(x=data["mass"],y=data["distance"],hue=data["method"],kind="scatter")

# %%
sns.relplot(x=data["mass"],y=data["year"],hue=data["method"],kind="line",color="red")
sns.set("paper")

# %% [markdown]
# # relationship between categorical and numerical variable

# %%
sns.catplot(x=data["method"],y=data["mass"], hue=data["number"],kind="bar")

# %%
sns.catplot(x=data["method"],y=data["distance"], hue=data["number"],kind="box")

# %%
sns.catplot(x=data["method"],y=data["distance"], hue=data["number"],kind="violin")

# %%
sns.catplot(x=data["method"],y=data["distance"], hue=data["number"],kind="point")

# %%
sns.catplot(x=data["method"],y=data["mass"], hue=data["number"],kind="strip")

# %%
sns.catplot(x=data["method"],y=data["mass"], hue=data["number"],kind="swarm")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 23.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 42.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 39.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 42.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # relationship between multiple variables

# %%
datac=data.iloc[:,1:]
datac2=data.iloc[:,1:-1]

# %%
sns.heatmap(datac.corr(),annot=True,cmap="coolwarm")
# Out:
# <Axes: >

# %%
#Regplot
sns.regplot(x=data["mass"],y=data["distance"],line_kws={"color":"red"})
# Out:
# <Axes: xlabel='mass', ylabel='distance'>

# %%
sns.jointplot(x=data["distance"],y=data["mass"],kind="reg")

# %%
import matplotlib.pyplot as plt
sea = sns.FacetGrid(data, col = "number", height = 2)
sea.map(sns.scatterplot, "mass", "distance",color="red")
plt.show ()
